# %%
pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# collect data

# %%
# clean and process that data

# %%
# analyse data

# %%
# visualise data

# %%
# make predictions with machine learning

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob'], 'Age': [25, 50]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   50

# %%
csv = pd.read_csv('https://drive.google.com/uc?id=1NW7EnwxuY6RpMIxOazRVibOYrZfMjsb2&export=download')
# print(csv.keys())

print(csv[csv['First Name'] == 'Dawn'])
# Out:
#        Index          User Id First Name Last Name     Sex  \
# 0          1  e09c4f4cbfEFaFd       Dawn   Trevino    Male
# 1969    1970  80B044b6bc29920       Dawn     Velez  Female
# 2244    2245  1cBbE29D4750f08       Dawn    Fields    Male
# 2705    2706  Aa1cb82ccE0CE58       Dawn     Wiley    Male
# 4195    4196  F4DAAeFA9efDBAb       Dawn    Mccall  Female
# ...      ...              ...        ...       ...     ...
# 93203  93204  20308eBc6d1FB2b       Dawn    Kelley    Male
# 93622  93623  ca13CEAC4EAf6a3       Dawn    Curtis    Male
# 94877  94878  FDedCF41e4Bd8e2       Dawn     Munoz  Female
# 96987  96988  5C70cB46AbD3255       Dawn    Galvan    Male
# 97714  97715  c3Cd13e251C6b3b       Dawn       Roy  Female
#
#                          Email                  Phone Date of birth  \
# 0      clintongood@example.org           360-423-5286    1972-01-17
# 1969   benderlance@example.org       001-282-814-4728    1997-11-30
# ...

# %%
csv = pd.read_csv('https://drive.google.com/uc?id=1NW7EnwxuY6RpMIxOazRVibOYrZfMjsb2&export=download')

# %%
print(csv[csv['First Name'] == 'Dawn'])
# Out:
#        Index          User Id First Name Last Name     Sex  \
# 0          1  e09c4f4cbfEFaFd       Dawn   Trevino    Male
# 1969    1970  80B044b6bc29920       Dawn     Velez  Female
# 2244    2245  1cBbE29D4750f08       Dawn    Fields    Male
# 2705    2706  Aa1cb82ccE0CE58       Dawn     Wiley    Male
# 4195    4196  F4DAAeFA9efDBAb       Dawn    Mccall  Female
# ...      ...              ...        ...       ...     ...
# 93203  93204  20308eBc6d1FB2b       Dawn    Kelley    Male
# 93622  93623  ca13CEAC4EAf6a3       Dawn    Curtis    Male
# 94877  94878  FDedCF41e4Bd8e2       Dawn     Munoz  Female
# 96987  96988  5C70cB46AbD3255       Dawn    Galvan    Male
# 97714  97715  c3Cd13e251C6b3b       Dawn       Roy  Female
#
#                          Email                  Phone Date of birth  \
# 0      clintongood@example.org           360-423-5286    1972-01-17
# 1969   benderlance@example.org       001-282-814-4728    1997-11-30
# ...

# %%
print(csv[csv['Last Name'] == 'Velez'])
# Out:
#        Index          User Id First Name Last Name     Sex  \
# 50        51  d1bD38103FFF2d8       Ruth     Velez    Male
# 315      316  1d4FCc86a4F4dC5     Elaine     Velez  Female
# 782      783  8Fdfcaa5BDDEbCf    Diamond     Velez  Female
# 1451    1452  FdBe554bDECFdEE      Bobby     Velez    Male
# 1969    1970  80B044b6bc29920       Dawn     Velez  Female
# ...      ...              ...        ...       ...     ...
# 95994  95995  34371938e61F19e       Alan     Velez    Male
# 98367  98368  4DfD47c6C62F58b      Jaime     Velez    Male
# 98546  98547  A30abCB4c57E8BE     Bailey     Velez  Female
# 98926  98927  Ff4dB51c0c8eEa1      Wyatt     Velez  Female
# 99145  99146  75dd92A70d2DC90      Frank     Velez    Male
#
#                               Email                   Phone Date of birth  \
# 50          briannayork@example.com           (215)082-5520    2014-05-20
# 315         wilsonapril@example.net   +1-195-670-2955x71026    1998-03-10
# ...

# %%
all_males = print(csv[csv['Sex'] == 'Male'])
# Out:
#         Index          User Id First Name Last Name   Sex  \
# 0           1  e09c4f4cbfEFaFd       Dawn   Trevino  Male
# 1           2  D781D28b845Ab9D       Dale  Mcknight  Male
# 4           5  9C4Df1246ddf543     Angela      Shea  Male
# 5           6  Ca64cDbaCE8E509     Edward     Marsh  Male
# 7           8  d54D30C5Ce7A20F     Jasmin   Collins  Male
# ...       ...              ...        ...       ...   ...
# 99993   99994  0B403873624F48c    Deborah      Reid  Male
# 99995   99996  eDbebb82Bdf859c    Eduardo   Fuentes  Male
# 99996   99997  78B30216f7Ad5eA     Marcus  Ferguson  Male
# 99997   99998  E0edBf053adCEc1    Marilyn    Benson  Male
# 99999  100000  FE35edEdE3BaC90     Jackie     Doyle  Male
#
#                              Email                  Phone Date of birth  \
# 0          clintongood@example.org           360-423-5286    1972-01-17
# 1       clairebradshaw@example.org             9062423229    1931-01-31
# ...

# %%
all_males.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 all_males.describe()
#
# AttributeError: 'NoneType' object has no attribute 'describe'

# %%
csv.describe()
# Out:
#                Index
# count  100000.000000
# mean    50000.500000
# std     28867.657797
# min         1.000000
# 25%     25000.750000
# 50%     50000.500000
# 75%     75000.250000
# max    100000.000000

# %%
female_teachers = csv[(csv['Sex'] == 'Female') & (csv['Job Title'].str.contains('teacher', case=False))]

female_teachers.to_csv('female_teachers.csv', index=False)

# %%
csv.keys()
# Out:
# Index(['Index', 'User Id', 'First Name', 'Last Name', 'Sex', 'Email', 'Phone',
#        'Date of birth', 'Job Title'],
#       dtype='object')
